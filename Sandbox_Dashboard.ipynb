# %%
from bokeh.sampledata.autompg import autompg_clean as df
import hvplot.pandas
import panel as pn
import holoviews as hv
import pandas as pd
hv.extension('bokeh')
pn.extension('tabulator')
PALETTE = ["#ff6f69", "#ffcc5c", "#88d8b0", ]
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
# ...

# %%
df = pd.read_csv('./dataframe/junghoon+test@rescale.com_2023-07-10 06:01:15 KST+0900.csv')
df['tags'] = df['tags'].str.strip("[]").str.split(",").str[0].str.strip().str.strip("'")
print(df.head())
(
    df[
        (df.owner == 'junghoon+test@rescale.com') &
        (df.template != 'True') &
        (df['core-hour'] != 0)
    ]
    .groupby(['tags', 'software', 'coretype', 'priority'])['core-hour'].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='tags')
).head(20)
# Out:
#     jobid  template                      owner projectid   tags  core-hour  \
# 0   qCJPd      True  junghoon+test@rescale.com     BKuia          0.000000
# 1   oMsRW     False  junghoon+test@rescale.com     BKuia  Trial  22.946667
# 2  bfkYeb     False  junghoon+test@rescale.com     BKuia  Trial  22.955556
# 3  PUjYeb     False  junghoon+test@rescale.com     BKuia  Trial  25.440000
# 4   HeYHW     False          shong@rescale.com       NaN          0.000000
#
#               software                          version   coretype  ncores  \
# 0  Simcenter STAR-CCM+      15.06.008 (Mixed Precision)    calcite      32
# 1               Abaqus     2021.HF9 (FlexNet Licensing)    kyanite      16
# 2               Abaqus  2021 Golden (FlexNet Licensing)    kyanite      16
# 3               Abaqus                             2017  calcitev2      16
# 4               Abaqus     2023 HF2 (FlexNet Licensing)     pyrite      24
#
#     priority
# 0  ON_DEMAND
# 1    INSTANT
# 2    INSTANT
# ...

# %%
idf = df.interactive()
